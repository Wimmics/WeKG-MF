# %% [markdown]
# # Join French Crop Usage (FCU) with TAXREF-LD via GEVES scientific names
#
# Join FCU with TAXREF-LD using GEVES as an intermediate because GEVES has most FCU varieties and provides scientific names.
# Process:
# - join FCU with GEVES: where FCU variety name = GEVES species name
# - join only the matched GEVES species names with the scientific names in TAXREF-LD

# %% [markdown]
# ### Initializations

# %%
import json
import os
from string import Template
import pandas as pd
from SPARQLWrapper import SPARQLWrapper, JSON, POST
from time import sleep
from math import isnan, nan

# %%
# Initializations
prefixes = '''
prefix api:            <http://ns.inria.fr/sparql-micro-service/api#>
prefix fcu:            <http://ontology.inrae.fr/frenchcropusage/>
prefix owl:            <http://www.w3.org/2002/07/owl#>
prefix rdf:            <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
prefix rdfs:           <http://www.w3.org/2000/01/rdf-schema#>
prefix skos:           <http://www.w3.org/2004/02/skos/core#>
prefix skosxl:         <http://www.w3.org/2008/05/skos-xl#>
prefix taxrefp:        <http://taxref.mnhn.fr/lod/property/>
prefix taxrefrk:       <http://taxref.mnhn.fr/lod/taxrank/>
prefix xsd:            <http://www.w3.org/2001/XMLSchema#>
'''

# %%
local_endpoint = 'http://localhost:8080/sparql'
fcu_endpoint = "http://ontology.inrae.fr/frenchcropusage/sparql"
taxref_endpoint = "https://taxref.mnhn.fr/sparql"
geves_endpoint = "http://graph.i3s.unice.fr/repositories/geves"

# %%
def exec_sparql(endpoint, query):
    """
    Execute a SPARQL query and return results as a Pandas DataFrame.
    Invocation uses the HTTP POST method. Requested result format is JSON.

    In case of failure, the function retries up to MAX_ATTEMPTS attempts while waiting increasing time between each attempt.
    An empty DataFrame is returned in case no attempt is successful.
    """
    # Max number of time a SPARQL query can fail before giving up
    MAX_ATTEMPTS = 3

    sparql = SPARQLWrapper(endpoint)
    sparql.setMethod(POST)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(query)
    
    attempt = 1;
    success = False
    while not success and attempt <= MAX_ATTEMPTS:
        try:
            raw_results = sparql.query()
            results = raw_results.convert()
        except:
            print(f'Error while executing SPARQL query (attempt {attempt}/{MAX_ATTEMPTS}).', end=' ')
            if attempt < MAX_ATTEMPTS:
                # Wait a few seconds before next attempt (5, 10, 15, ...)
                print(f'Will retry in {attempt * 5}s.')
                sleep(attempt * 5)
        else:
            success = True
        finally:
            attempt = attempt + 1

    if success:
        if 'head' in results and 'results' in results:
            cols = results['head']['vars']
            out = []
            for row in results['results']['bindings']:
                item = []
                for c in cols:
                    item.append(row.get(c, {}).get('value'))
                out.append(item)
            return pd.DataFrame(out, columns=cols)
        else:
            print('Invalid SPARQL result. Will return empty DataFrame.\n' + str(results))
    else:
        print(f'Unable to execute SPARQL query after {MAX_ATTEMPTS} attempts. Will return empty DataFarme.')
                  
    return pd.DataFrame()            


def dataframe_preview(df, start=0, end=10):
    print("== Number of lines: " + str(df.shape[0]))
    print("== Number of unique values:")
    print(df.nunique())
    display(df[start:end])

# %% [markdown]
# ---
# ## Join FCU with GEVES: FCU varieties names = GEVES species

# %%
query =  prefixes + '''
select distinct ?fcu_concept ?fcu_name ?fcu_name_type ?geves_lab_spe_dus ?geves_scientific_name where {

    # Query FCU crops
    service <http://ontology.inrae.fr/frenchcropusage/sparql> {
        select distinct ?fcu_concept ?fcu_name ?fcu_name_type where {

            # Select only cultivated crops
            <http://ontology.inrae.fr/frenchcropusage/Usages_plantes_cultivees> skos:narrower+ ?fcu_concept.

            # Keep only leaves or their direct parent but not above
            FILTER (NOT EXISTS { ?fcu_concept skos:narrower/skos:narrower ?child. })

            # Get prefered and alternate labels and keep track of the type of label
            # ?fcu_concept a skos:Concept.
            { ?fcu_concept skos:prefLabel ?lb. bind("pref" as ?fcu_name_type) }
            UNION
            { ?fcu_concept skos:altLabel  ?lb. bind("alt" as ?fcu_name_type) }

            bind(str(lcase(?lb)) as ?fcu_name)
        } order by ?fcu_concept
    }

    # Query GEVES
    optional {
        service <http://graph.i3s.unice.fr/repositories/geves> {
            [] 
                api:lab_spe_bota ?lab_spe_bota;
                api:lab_spe_dus ?geves_lab_spe_dus.
            bind(str(lcase(?lab_spe_bota))      as ?geves_scientific_name)
            bind(str(lcase(?geves_lab_spe_dus)) as ?geves_species)
        }

        # Match the GEVES species names and the FCU preferred/alternate labels:
        filter (?fcu_name = ?geves_species) 
    }
}'''

# %%
# %time df_fcu_geves = exec_sparql(local_endpoint, query)
# Out:
# Wall time: 13.4 s

# %%
dataframe_preview(df_fcu_geves, end=10)
# Out:
# == Number of lines: 1521
# == Number of unique values:
# fcu_concept               446
# fcu_name                 1481
# fcu_name_type               2
# geves_lab_spe_dus          89
# geves_scientific_name      85
# dtype: int64
#                                          fcu_concept                 fcu_name  \
# 0  http://ontology.inrae.fr/frenchcropusage/Arbre...   arbre fruitier à noyau
# 1  http://ontology.inrae.fr/frenchcropusage/Arbre...            arbre à noyau
# 2  http://ontology.inrae.fr/frenchcropusage/Arbre...            fruit à noyau
# 3  http://ontology.inrae.fr/frenchcropusage/Abric...               abricotier
# 4  http://ontology.inrae.fr/frenchcropusage/Abric...                  abricot
# 5  http://ontology.inrae.fr/frenchcropusage/Abric...          abricotier pays
# 6  http://ontology.inrae.fr/frenchcropusage/Abric...             abricot pays
# 7  http://ontology.inrae.fr/frenchcropusage/Abric...  abricotier des antilles
# 8  http://ontology.inrae.fr/frenchcropusage/Abric...                    mamey
# 9  http://ontology.inrae.fr/frenchcropusage/Abric...          abricotier-pays
#
#   fcu_name_type geves_lab_spe_dus geves_scientific_name
# 0          pref              None                  None
# 1           alt              None                  None
# 2           alt              None                  None
# 3          pref        Abricotier   prunus armeniaca l.
# 4           alt              None                  None
# 5          pref              None                  None
# 6           alt              None                  None
# 7           alt              None                  None
# 8           alt              None                  None
# 9           alt              None                  None

# %%
#df_fcu_geves.to_csv("result1_fcu_geves.csv", index=False)
df_fcu_geves.to_excel("result1_fcu_geves.xlsx")
#df_fcu_geves = pd.read_csv("result1_fcu_geves.csv")

# %% [markdown]
# #### Count only matches

# %%
dataframe_preview(df_fcu_geves.dropna())
# Out:
# == Number of lines: 98
# == Number of unique values:
# fcu_concept              91
# fcu_name                 89
# fcu_name_type             2
# geves_lab_spe_dus        89
# geves_scientific_name    85
# dtype: int64
#                                            fcu_concept        fcu_name  \
# 3    http://ontology.inrae.fr/frenchcropusage/Abric...      abricotier
# 37   http://ontology.inrae.fr/frenchcropusage/Ceris...  cerisier acide
# 38   http://ontology.inrae.fr/frenchcropusage/Ceris...   cerisier doux
# 39   http://ontology.inrae.fr/frenchcropusage/Ceris...   cerisier doux
# 54    http://ontology.inrae.fr/frenchcropusage/Pechers          pêcher
# 62   http://ontology.inrae.fr/frenchcropusage/Pruniers         prunier
# 153  http://ontology.inrae.fr/frenchcropusage/Cassi...          cassis
# 154  http://ontology.inrae.fr/frenchcropusage/Framb...     framboisier
# 156  http://ontology.inrae.fr/frenchcropusage/Grose...     groseillier
# 181  http://ontology.inrae.fr/frenchcropusage/Citro...      citronnier
#
#     fcu_name_type geves_lab_spe_dus       geves_scientific_name
# 3            pref        Abricotier         prunus armeniaca l.
# 37            alt    Cerisier acide           prunus cerasus l.
# 38            alt     Cerisier doux             prunus avium l.
# 39            alt     Cerisier doux           prunus cerasus l.
# 54           pref            Pêcher  prunus persica (l.) batsch
# 62           pref           Prunier         prunus domestica l.
# 153           alt            Cassis             ribes nigrum l.
# 154          pref       Framboisier             rubus idaeus l.
# 156          pref       Groseillier             ribes rubrum l.
# 181          pref        Citronnier     citrus limon (l.) burm.

# %% [markdown]
# ### Matches:
# - FCU: 91 unique concepts, 89 unique labels
# - GEVES: 89 unique species, 85 unique scientific names

# %% [markdown]
# ---
# ## Join GEVES with TAXREF-LD on scientific name, only on the GEVES species matched with FCU

# %%
# SPARQL query to TAXREF-LD to match a single GEVES scientific name (placeholder $geves_scientific_name)
queryTpl = Template(prefixes + '''
    select distinct ("$geves_scientific_name" as ?geves_scientific_name) ?taxref_full_name ?taxref_name_type ?taxon ?rank 
    from <http://taxref.mnhn.fr/lod/graph/classes/13.0>
    from <http://taxref.mnhn.fr/lod/graph/concepts/13.0>
    where {
        # ?name
           a                      skos:Concept, <http://rs.tdwg.org/ontology/voc/TaxonName#TaxonName>;
           rdfs:label             ?taxref_full_name.
           
        { ?name taxrefp:isReferenceNameOf ?taxon. bind("pref" as ?taxref_name_type) }
        union
        { ?name taxrefp:isSynonymOf       ?taxon. bind("alt" as ?taxref_name_type) }

        # ?taxon
           taxrefp:hasRank        ?rank.

        # All ranks up to spcecies but not above
        filter (?rank in (
            taxrefrk:Species,  taxrefrk:SemiSpecies, taxrefrk:MicroSpecies, taxrefrk:SubSpecies, taxrefrk:Natio, 
            taxrefrk:Varietas, taxrefrk:SubVarietas, taxrefrk:Forma,        taxrefrk:SubForma,   taxrefrk:FormaSpecies,
            taxrefrk:Linea,    taxrefrk:Clone,       taxrefrk:Race,         taxrefrk:Cultivar,   taxrefrk:Morpha,
            taxrefrk:Abberatio ))
        
        # TAXREF names have the authority and date, whereas GEVES names do not have the date.
        # => match the GEVES name as a subpart of the TAXREF name
        bind(str(lcase(?taxref_full_name)) as ?taxref_scn_sl)
        filter(strstarts(?taxref_scn_sl, "$geves_scientific_name"))
    }
''')

# %%
# Set a max number of queries to submit. 0 = unlimited.
MAX_QUERIES = 0

# Result DataFrame
df_geves_taxref = pd.DataFrame()

idx = 1
df_fcu_geves_matched = df_fcu_geves.dropna()
unique_names = df_fcu_geves_matched.geves_scientific_name.unique()
for geves_scientific_name in unique_names:
    query = queryTpl.substitute(geves_scientific_name = geves_scientific_name.strip().lower())
    #print(query)
    
    print(f"---- Running query {idx}/{len(unique_names)} - geves_scientific_name = {geves_scientific_name}")
    # %time _df = exec_sparql(taxref_endpoint, query)
    print(f'Number of results: {_df.shape[0]}')
    df_geves_taxref = df_geves_taxref.append(_df)
    
    # Keep track of GEVES names not matched with TAXREF
    if _df.shape[0] == 0:
        nomatch_row = {'taxref_full_name': None, 'taxref_name_type': None, 'taxon': None, 'geves_scientific_name': geves_scientific_name.strip().lower()}
        df_geves_taxref = df_geves_taxref.append(nomatch_row, ignore_index=True)
    
    idx = idx + 1
    if MAX_QUERIES > 0 and idx > MAX_QUERIES:
        break
# Out:
# ---- Running query 1/85 - geves_scientific_name = prunus armeniaca l.
# Wall time: 14.4 s
# Number of results: 1
# ---- Running query 2/85 - geves_scientific_name = prunus cerasus l.
# Wall time: 14.3 s
# Number of results: 1
# ---- Running query 3/85 - geves_scientific_name = prunus avium l.
# Wall time: 13.7 s
# Number of results: 0
# ---- Running query 4/85 - geves_scientific_name = prunus persica (l.) batsch
# Wall time: 12.8 s
# Number of results: 1
# ---- Running query 5/85 - geves_scientific_name = prunus domestica l.
# Wall time: 11.7 s
# Number of results: 1
# ---- Running query 6/85 - geves_scientific_name = ribes nigrum l.
# Wall time: 12.3 s
# Number of results: 1
# ---- Running query 7/85 - geves_scientific_name = rubus idaeus l.
# Wall time: 12.3 s
# Number of results: 1
# ---- Running query 8/85 - geves_scientific_name = ribes rubrum l.
# Wall time: 14.3 s
# Number of results: 1
# ---- Running query 9/85 - geves_scientific_name = citrus limon (l.) burm.
# Wall time: 13.1 s
# Number of results: 1
# ---- Running query 10/85 - geves_scientific_name = citrus clementina hort. ex. tan.
# Wall time: 13.2 s
# Number of results: 0
# ---- Running query 11/85 - geves_scientific_name = citrus deliciosa ten.
# Wall time: 12.5 s
# Number of results: 1
# ---- Running query 12/85 - geves_scientific_name = citrus sinensis (l.) osb.
# Wall time: 14.2 s
# Number of results: 0
# ---- Running query 13/85 - geves_scientific_name = citrus paradisi macf.
# Wall time: 14.6 s
# Number of results: 0
# ---- Running query 14/85 - geves_scientific_name = citrus reticulata blanco x citrus sinensis (l.) osb.
# Wall time: 13.5 s
# Number of results: 0
# ---- Running query 15/85 - geves_scientific_name = citrus medica l.
# Wall time: 13.4 s
# Number of results: 1
# ---- Running query 16/85 - geves_scientific_name = prunus amygdalus bartock
# Wall time: 12.4 s
# Number of results: 0
# ---- Running query 17/85 - geves_scientific_name = castanea vulgaris
# Wall time: 12.9 s
# Number of results: 1
# ---- Running query 18/85 - geves_scientific_name = corylus avellana l.
# Wall time: 11.2 s
# Number of results: 1
# ---- Running query 19/85 - geves_scientific_name = juglans regia l.
# Wall time: 13.1 s
# Number of results: 1
# ---- Running query 20/85 - geves_scientific_name = malus domestica borkh.
# Wall time: 13.2 s
# Number of results: 1
# ---- Running query 21/85 - geves_scientific_name = fragaria xananassa duch.
# Wall time: 13 s
# Number of results: 0
# ---- Running query 22/85 - geves_scientific_name = beta vulgaris l. ssp. vulgaris var. altissima doell
# Wall time: 14.9 s
# Number of results: 0
# ---- Running query 23/85 - geves_scientific_name = cichorium intybus l.
# Wall time: 12.9 s
# Number of results: 1
# ---- Running query 24/85 - geves_scientific_name = brassica napus l.
# Wall time: 14.1 s
# Number of results: 1
# ---- Running query 25/85 - geves_scientific_name = brassica juncea (l.) czern.
# Wall time: 14.1 s
# Number of results: 1
# ---- Running query 26/85 - geves_scientific_name = avena sativa l.
# Wall time: 13.7 s
# Number of results: 1
# ---- Running query 27/85 - geves_scientific_name = avena nuda l.
# Wall time: 14.5 s
# Number of results: 1
# ---- Running query 28/85 - geves_scientific_name = avena strigosa schreb.
# Wall time: 13.2 s
# Number of results: 1
# ---- Running query 29/85 - geves_scientific_name = triticum durum desf.
# Wall time: 12.8 s
# Number of results: 1
# ---- Running query 30/85 - geves_scientific_name = triticum aestivum l.
# Wall time: 13.8 s
# Number of results: 1
# ---- Running query 31/85 - geves_scientific_name = hordeum vulgare l.
# Wall time: 14.8 s
# Number of results: 1
# ---- Running query 32/85 - geves_scientific_name = sorghum bicolor (l.) moench
# Wall time: 12.5 s
# Number of results: 1
# ---- Running query 33/85 - geves_scientific_name = sorghum sudanense (piper)
# Wall time: 14.2 s
# Number of results: 1
# ---- Running query 34/85 - geves_scientific_name = sorghum bicolor (l.) x sorghum sudanense (piper)
# Wall time: 13.3 s
# Number of results: 0
# ---- Running query 35/85 - geves_scientific_name = ×triticosecale wittm. ex a. camus
# Wall time: 13.6 s
# Number of results: 0
# ---- Running query 36/85 - geves_scientific_name = oryza sativa l.
# Wall time: 13.8 s
# Number of results: 1
# ---- Running query 37/85 - geves_scientific_name = cicer arietinum l.
# Wall time: 12.3 s
# Number of results: 1
# ---- Running query 38/85 - geves_scientific_name = lupinus albus l.
# Wall time: 12.6 s
# Number of results: 1
# ---- Running query 39/85 - geves_scientific_name = pisum sativum l.
# Wall time: 12 s
# Number of results: 1
# ---- Running query 40/85 - geves_scientific_name = allium schoenoprasum l.
# Wall time: 13.7 s
# Number of results: 1
# ---- Running query 41/85 - geves_scientific_name = foeniculum vulgare mill.
# Wall time: 14 s
# Number of results: 1
# ---- Running query 42/85 - geves_scientific_name = petroselinum crispum (mill.) nyman ex a. w. hill
# Wall time: 13.4 s
# Number of results: 0
# ---- Running query 43/85 - geves_scientific_name = brassica rapa l. subsp. campestris (l.) a. r. clapham
# Wall time: 14.5 s
# Number of results: 0
# ---- Running query 44/85 - geves_scientific_name = vicia pannonica crantz
# Wall time: 13 s
# Number of results: 1
# ---- Running query 45/85 - geves_scientific_name = trifolium incarnatum l.
# Wall time: 15.5 s
# Number of results: 1
# ---- Running query 46/85 - geves_scientific_name = beta vulgaris l. ssp. vulgaris var. alba dc
# Wall time: 15.7 s
# Number of results: 0
# ---- Running query 47/85 - geves_scientific_name = brassica oleracea l. convar. acephala ( dc. ) alef. var. medullosa thell.+ var. viridis
# Wall time: 16.2 s
# Number of results: 0
# ---- Running query 48/85 - geves_scientific_name = raphanus sativus l. var. oleiformis pers.
# Wall time: 15.1 s
# Number of results: 0
# ---- Running query 49/85 - geves_scientific_name = lotus corniculatus l.
# Wall time: 13.5 s
# Number of results: 1
# ---- Running query 50/85 - geves_scientific_name = medicago sativa l.
# Wall time: 12 s
# Number of results: 1
# ---- Running query 51/85 - geves_scientific_name = trifolium michelianum savi var. balansae (boiss.) azn.
# Wall time: 13.9 s
# Number of results: 0
# ---- Running query 52/85 - geves_scientific_name = onobrychis viciifolia scop.
# Wall time: 12.2 s
# Number of results: 1
# ---- Running query 53/85 - geves_scientific_name = trifolium repens l.
# Wall time: 12.6 s
# Number of results: 1
# ---- Running query 54/85 - geves_scientific_name = trifolium pratense l.
# Wall time: 12 s
# Number of results: 1
# ---- Running query 55/85 - geves_scientific_name = trifolium hybridum l.
# Wall time: 14.8 s
# Number of results: 1
# ---- Running query 56/85 - geves_scientific_name = lolium × boucheanum kunth
# Wall time: 13.3 s
# Number of results: 0
# ---- Running query 57/85 - geves_scientific_name = trifolium alexandrinum l.
# Wall time: 13.6 s
# Number of results: 1
# ---- Running query 58/85 - geves_scientific_name = phacelia tanacetifolia benth.
# Wall time: 12.9 s
# Number of results: 1
# ---- Running query 59/85 - geves_scientific_name = trigonella foenum-graecum l.
# Wall time: 12.9 s
# Number of results: 1
# ---- Running query 60/85 - geves_scientific_name = allium sativum l.
# Wall time: 14.7 s
# Number of results: 1
# ---- Running query 61/85 - geves_scientific_name = allium cepa l.
# Wall time: 14.8 s
# Number of results: 1
# ---- Running query 62/85 - geves_scientific_name = allium porrum l.
# Wall time: 13.4 s
# Number of results: 1
# ---- Running query 63/85 - geves_scientific_name = lactuca sativa l.
# Wall time: 13.4 s
# Number of results: 1
# ---- Running query 64/85 - geves_scientific_name = valerianella locusta (l.) laterr.
# Wall time: 13.1 s
# Number of results: 1
# ---- Running query 65/85 - geves_scientific_name = brassica oleracea l. var. gemmifera zenker
# Wall time: 12.9 s
# Number of results: 0
# ---- Running query 66/85 - geves_scientific_name = brassica oleracea l. convar. capitata (l.) alef. var. alba dc.
# Wall time: 12.3 s
# Number of results: 0
# ---- Running query 67/85 - geves_scientific_name = brassica oleracea l. convar. capitata (l.) alef. var. sabauda l.
# Wall time: 13.5 s
# Number of results: 0
# ---- Running query 68/85 - geves_scientific_name = brassica oleracea l. convar. capitata (l.) alef. var. rubra (l.) thell.
# Wall time: 14.3 s
# Number of results: 0
# ---- Running query 69/85 - geves_scientific_name = brassica pekinensis ( lour. ) rupr.
# Wall time: 13.5 s
# Number of results: 0
# ---- Running query 70/85 - geves_scientific_name = beta vulgaris l. ssp. vulgaris var. flavescens dc. f. crispa
# Wall time: 12.6 s
# Number of results: 0
# ---- Running query 71/85 - geves_scientific_name = cynara scolymus
# Wall time: 12 s
# Number of results: 3
# ---- Running query 72/85 - geves_scientific_name = cynara cardunculus l.
# Wall time: 12.6 s
# Number of results: 1
# ---- Running query 73/85 - geves_scientific_name = brassica oleracea l. convar. botrytis (l.) alef. var. cymosa duch.
# Wall time: 12.9 s
# Number of results: 0
# ---- Running query 74/85 - geves_scientific_name = brassica oleracea l. convar. botrytis (l.) alef. var. botrytis
# Wall time: 13.2 s
# Number of results: 0
# ---- Running query 75/85 - geves_scientific_name = asparagus officinalis l.
# Wall time: 13.8 s
# Number of results: 1
# ---- Running query 76/85 - geves_scientific_name = brassica oleracea l. convar. acephala (dc.) alef. var. gongylodes
# Wall time: 14.3 s
# Number of results: 0
# ---- Running query 77/85 - geves_scientific_name = solanum melongena l.
# Wall time: 14.3 s
# Number of results: 1
# ---- Running query 78/85 - geves_scientific_name = cucurbita maxima duchesne
# Wall time: 12.3 s
# Number of results: 1
# ---- Running query 79/85 - geves_scientific_name = cucurbita pepo l.
# Wall time: 12.7 s
# Number of results: 1
# ---- Running query 80/85 - geves_scientific_name = cucumis melo l.
# Wall time: 13.2 s
# Number of results: 1
# ---- Running query 81/85 - geves_scientific_name = solanum lycopersicum l.
# Wall time: 14.8 s
# Number of results: 1
# ---- Running query 82/85 - geves_scientific_name = apium graveolens l.
# Wall time: 13.7 s
# Number of results: 1
# ---- Running query 83/85 - geves_scientific_name = phaseolus coccineus l.
# Wall time: 13.5 s
# Number of results: 1
# ---- Running query 84/85 - geves_scientific_name = beta vulgaris l. ssp. vulgaris var. saccharifera alef.
# Wall time: 13.5 s
# Number of results: 0
# ---- Running query 85/85 - geves_scientific_name = raphanus sativus l. var. niger
# Wall time: 13.2 s
# Number of results: 0

# %%
#df_geves_taxref.to_csv("result2_geves_taxref.csv", index=False)
df_geves_taxref.to_excel("result2_geves_taxref.xlsx")
#df_geves_taxref = pd.read_csv("result2_geves_taxref.csv")

# %%
dataframe_preview(df_geves_taxref)
# Out:
# == Number of lines: 87
# == Number of unique values:
# geves_scientific_name    85
# taxref_full_name         59
# taxref_name_type          2
# taxon                    57
# rank                      2
# dtype: int64
#               geves_scientific_name                  taxref_full_name  \
# 0               prunus armeniaca l.         Prunus armeniaca L., 1753
# 1                 prunus cerasus l.           Prunus cerasus L., 1753
# 2                   prunus avium l.                              None
# 3        prunus persica (l.) batsch  Prunus persica (L.) Batsch, 1801
# 4               prunus domestica l.         Prunus domestica L., 1753
# 5                   ribes nigrum l.             Ribes nigrum L., 1753
# 6                   rubus idaeus l.             Rubus idaeus L., 1753
# 7                   ribes rubrum l.             Ribes rubrum L., 1753
# 8           citrus limon (l.) burm.   Citrus limon (L.) Burm.f., 1768
# 9  citrus clementina hort. ex. tan.                              None
#
#   taxref_name_type                                        taxon  \
# 0             pref  http://taxref.mnhn.fr/lod/taxon/116041/13.0
# 1             pref  http://taxref.mnhn.fr/lod/taxon/116054/13.0
# 2             None                                         None
# 3             pref  http://taxref.mnhn.fr/lod/taxon/116112/13.0
# 4             pref  http://taxref.mnhn.fr/lod/taxon/116067/13.0
# 5             pref  http://taxref.mnhn.fr/lod/taxon/117766/13.0
# 6             pref  http://taxref.mnhn.fr/lod/taxon/119149/13.0
# 7             pref  http://taxref.mnhn.fr/lod/taxon/117774/13.0
# 8             pref   http://taxref.mnhn.fr/lod/taxon/91809/13.0
# 9             None                                         None
#
#                                         rank
# 0  http://taxref.mnhn.fr/lod/taxrank/Species
# 1  http://taxref.mnhn.fr/lod/taxrank/Species
# 2                                        NaN
# 3  http://taxref.mnhn.fr/lod/taxrank/Species
# 4  http://taxref.mnhn.fr/lod/taxrank/Species
# 5  http://taxref.mnhn.fr/lod/taxrank/Species
# 6  http://taxref.mnhn.fr/lod/taxrank/Species
# 7  http://taxref.mnhn.fr/lod/taxrank/Species
# 8  http://taxref.mnhn.fr/lod/taxrank/Species
# 9                                        NaN

# %% [markdown]
# #### Count only matches

# %%
dataframe_preview(df_geves_taxref.dropna())
# Out:
# == Number of lines: 59
# == Number of unique values:
# geves_scientific_name    57
# taxref_full_name         59
# taxref_name_type          2
# taxon                    57
# rank                      2
# dtype: int64
#          geves_scientific_name                  taxref_full_name  \
# 0          prunus armeniaca l.         Prunus armeniaca L., 1753
# 1            prunus cerasus l.           Prunus cerasus L., 1753
# 3   prunus persica (l.) batsch  Prunus persica (L.) Batsch, 1801
# 4          prunus domestica l.         Prunus domestica L., 1753
# 5              ribes nigrum l.             Ribes nigrum L., 1753
# 6              rubus idaeus l.             Rubus idaeus L., 1753
# 7              ribes rubrum l.             Ribes rubrum L., 1753
# 8      citrus limon (l.) burm.   Citrus limon (L.) Burm.f., 1768
# 10       citrus deliciosa ten.       Citrus deliciosa Ten., 1840
# 14            citrus medica l.            Citrus medica L., 1753
#
#    taxref_name_type                                        taxon  \
# 0              pref  http://taxref.mnhn.fr/lod/taxon/116041/13.0
# 1              pref  http://taxref.mnhn.fr/lod/taxon/116054/13.0
# 3              pref  http://taxref.mnhn.fr/lod/taxon/116112/13.0
# 4              pref  http://taxref.mnhn.fr/lod/taxon/116067/13.0
# 5              pref  http://taxref.mnhn.fr/lod/taxon/117766/13.0
# 6              pref  http://taxref.mnhn.fr/lod/taxon/119149/13.0
# 7              pref  http://taxref.mnhn.fr/lod/taxon/117774/13.0
# 8              pref   http://taxref.mnhn.fr/lod/taxon/91809/13.0
# 10              alt   http://taxref.mnhn.fr/lod/taxon/91812/13.0
# 14             pref   http://taxref.mnhn.fr/lod/taxon/91811/13.0
#
#                                          rank
# 0   http://taxref.mnhn.fr/lod/taxrank/Species
# 1   http://taxref.mnhn.fr/lod/taxrank/Species
# 3   http://taxref.mnhn.fr/lod/taxrank/Species
# 4   http://taxref.mnhn.fr/lod/taxrank/Species
# 5   http://taxref.mnhn.fr/lod/taxrank/Species
# 6   http://taxref.mnhn.fr/lod/taxrank/Species
# 7   http://taxref.mnhn.fr/lod/taxrank/Species
# 8   http://taxref.mnhn.fr/lod/taxrank/Species
# 10  http://taxref.mnhn.fr/lod/taxrank/Species
# 14  http://taxref.mnhn.fr/lod/taxrank/Species

# %% [markdown]
# ### Matches:
# - GEVES: 57 unique scientific names
# - TAXREF-LD: 57 unique taxa
#
# => 32 GEVES names not matched with TAXREF-LD

# %% [markdown]
# ---
# ## Join intermediate results: FCU-GEVES and GEVES-TAXREFLD

# %%
df_merge = pd.merge(df_fcu_geves, df_geves_taxref, on="geves_scientific_name", how='left')
df_merge.drop_duplicates(inplace=True)
dataframe_preview(df_merge)
# Out:
# == Number of lines: 1523
# == Number of unique values:
# fcu_concept               446
# fcu_name                 1481
# fcu_name_type               2
# geves_lab_spe_dus          89
# geves_scientific_name      85
# taxref_full_name           59
# taxref_name_type            2
# taxon                      57
# rank                        2
# dtype: int64
#                                          fcu_concept                 fcu_name  \
# 0  http://ontology.inrae.fr/frenchcropusage/Arbre...   arbre fruitier à noyau
# 1  http://ontology.inrae.fr/frenchcropusage/Arbre...            arbre à noyau
# 2  http://ontology.inrae.fr/frenchcropusage/Arbre...            fruit à noyau
# 3  http://ontology.inrae.fr/frenchcropusage/Abric...               abricotier
# 4  http://ontology.inrae.fr/frenchcropusage/Abric...                  abricot
# 5  http://ontology.inrae.fr/frenchcropusage/Abric...          abricotier pays
# 6  http://ontology.inrae.fr/frenchcropusage/Abric...             abricot pays
# 7  http://ontology.inrae.fr/frenchcropusage/Abric...  abricotier des antilles
# 8  http://ontology.inrae.fr/frenchcropusage/Abric...                    mamey
# 9  http://ontology.inrae.fr/frenchcropusage/Abric...          abricotier-pays
#
#   fcu_name_type geves_lab_spe_dus geves_scientific_name  \
# 0          pref              None                  None
# 1           alt              None                  None
# 2           alt              None                  None
# 3          pref        Abricotier   prunus armeniaca l.
# 4           alt              None                  None
# 5          pref              None                  None
# 6           alt              None                  None
# 7           alt              None                  None
# 8           alt              None                  None
# 9           alt              None                  None
#
#             taxref_full_name taxref_name_type  \
# 0                        NaN              NaN
# 1                        NaN              NaN
# 2                        NaN              NaN
# 3  Prunus armeniaca L., 1753             pref
# 4                        NaN              NaN
# 5                        NaN              NaN
# 6                        NaN              NaN
# 7                        NaN              NaN
# 8                        NaN              NaN
# 9                        NaN              NaN
#
#                                          taxon  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3  http://taxref.mnhn.fr/lod/taxon/116041/13.0
# 4                                          NaN
# 5                                          NaN
# 6                                          NaN
# 7                                          NaN
# 8                                          NaN
# 9                                          NaN
#
#                                         rank
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3  http://taxref.mnhn.fr/lod/taxrank/Species
# 4                                        NaN
# 5                                        NaN
# 6                                        NaN
# 7                                        NaN
# 8                                        NaN
# 9                                        NaN

# %%
#df_merge.to_csv("result3_fcu_geves_taxref.csv", index=False)
df_merge.to_excel("result3_fcu_geves_taxref.xlsx")
#df_merge = pd.read_csv("result3_fcu_geves_taxref.csv")

# %% [markdown]
# #### Count only matches

# %%
dataframe_preview(df_merge.dropna())
# Out:
# == Number of lines: 70
# == Number of unique values:
# fcu_concept              64
# fcu_name                 63
# fcu_name_type             2
# geves_lab_spe_dus        63
# geves_scientific_name    57
# taxref_full_name         59
# taxref_name_type          2
# taxon                    57
# rank                      2
# dtype: int64
#                                            fcu_concept        fcu_name  \
# 3    http://ontology.inrae.fr/frenchcropusage/Abric...      abricotier
# 37   http://ontology.inrae.fr/frenchcropusage/Ceris...  cerisier acide
# 39   http://ontology.inrae.fr/frenchcropusage/Ceris...   cerisier doux
# 54    http://ontology.inrae.fr/frenchcropusage/Pechers          pêcher
# 62   http://ontology.inrae.fr/frenchcropusage/Pruniers         prunier
# 153  http://ontology.inrae.fr/frenchcropusage/Cassi...          cassis
# 154  http://ontology.inrae.fr/frenchcropusage/Framb...     framboisier
# 156  http://ontology.inrae.fr/frenchcropusage/Grose...     groseillier
# 181  http://ontology.inrae.fr/frenchcropusage/Citro...      citronnier
# 192  http://ontology.inrae.fr/frenchcropusage/Manda...     mandarinier
#
#     fcu_name_type geves_lab_spe_dus       geves_scientific_name  \
# 3            pref        Abricotier         prunus armeniaca l.
# 37            alt    Cerisier acide           prunus cerasus l.
# 39            alt     Cerisier doux           prunus cerasus l.
# 54           pref            Pêcher  prunus persica (l.) batsch
# 62           pref           Prunier         prunus domestica l.
# 153           alt            Cassis             ribes nigrum l.
# 154          pref       Framboisier             rubus idaeus l.
# 156          pref       Groseillier             ribes rubrum l.
# 181          pref        Citronnier     citrus limon (l.) burm.
# 192          pref       Mandarinier       citrus deliciosa ten.
#
#                      taxref_full_name taxref_name_type  \
# 3           Prunus armeniaca L., 1753             pref
# 37            Prunus cerasus L., 1753             pref
# 39            Prunus cerasus L., 1753             pref
# 54   Prunus persica (L.) Batsch, 1801             pref
# 62          Prunus domestica L., 1753             pref
# 153             Ribes nigrum L., 1753             pref
# 154             Rubus idaeus L., 1753             pref
# 156             Ribes rubrum L., 1753             pref
# 181   Citrus limon (L.) Burm.f., 1768             pref
# 192       Citrus deliciosa Ten., 1840              alt
#
#                                            taxon  \
# 3    http://taxref.mnhn.fr/lod/taxon/116041/13.0
# 37   http://taxref.mnhn.fr/lod/taxon/116054/13.0
# 39   http://taxref.mnhn.fr/lod/taxon/116054/13.0
# 54   http://taxref.mnhn.fr/lod/taxon/116112/13.0
# 62   http://taxref.mnhn.fr/lod/taxon/116067/13.0
# 153  http://taxref.mnhn.fr/lod/taxon/117766/13.0
# 154  http://taxref.mnhn.fr/lod/taxon/119149/13.0
# 156  http://taxref.mnhn.fr/lod/taxon/117774/13.0
# 181   http://taxref.mnhn.fr/lod/taxon/91809/13.0
# 192   http://taxref.mnhn.fr/lod/taxon/91812/13.0
#
#                                           rank
# 3    http://taxref.mnhn.fr/lod/taxrank/Species
# 37   http://taxref.mnhn.fr/lod/taxrank/Species
# 39   http://taxref.mnhn.fr/lod/taxrank/Species
# 54   http://taxref.mnhn.fr/lod/taxrank/Species
# 62   http://taxref.mnhn.fr/lod/taxrank/Species
# 153  http://taxref.mnhn.fr/lod/taxrank/Species
# 154  http://taxref.mnhn.fr/lod/taxrank/Species
# 156  http://taxref.mnhn.fr/lod/taxrank/Species
# 181  http://taxref.mnhn.fr/lod/taxrank/Species
# 192  http://taxref.mnhn.fr/lod/taxrank/Species

# %% [markdown]
# ### Matches
# - FCU: 64 unique concepts, 63 unique labels
# - TAXREF-LD: 57 unique taxa from 2 ranks
